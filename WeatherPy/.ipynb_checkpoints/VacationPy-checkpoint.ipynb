# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 0        0            lupane -18.9315   27.8070      7.32        47
# 1        1         adamstown -25.0660 -130.1015     21.78        80
# 2        2        karymskoye  51.6167  114.3500     17.89        92
# 3        3  minas de marcona -15.2119  -75.1103     12.36        87
# 4        4          midvagur  62.0511   -7.1939     10.46        93
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        2.26      ZW  1687832060
# 1          22        9.35      PN  1687832060
# 2         100        0.84      RU  1687832060
# 3          55        5.60      PE  1687832060
# 4          75        1.54      FO  1687832061

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points("Lng", "Lat", geo=True, size = "Humidity", color = "City", tiles = "OSM", height=400, width=1000)
# Display the map 
city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_ideal = city_data_df.loc[(city_data_df['Max Temp'] >= 18.333) & 
                                   (city_data_df['Cloudiness'] == 0) & 
                                   (city_data_df['Humidity'] <= 60)]
# Drop any rows with null values
city_data_ideal.dropna()

# Display sample data
city_data_ideal
# Out:
#      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 88        88                   bazarak  35.3129   69.5152     21.16        47
# 91        91               sao vicente -23.9631  -46.3919     24.59        26
# 92        92           duque de caxias -22.7856  -43.3117     22.71        60
# 94        94                   winslow  35.0242 -110.6974     33.10        11
# 117      117  petropavlovsk-kamchatsky  53.0452  158.6483     25.33        53
# 120      120                   pahrump  36.2083 -115.9839     32.36        11
# 132      132                siwa oasis  29.2041   25.5195     26.50        45
# 135      135                   the pas  53.8251 -101.2541     20.01        49
# 150      150                      brak  27.5496   14.2714     28.28        29
# 157      157                    ifrane  33.3333   -5.2500     22.20        20
# 180      180               as sulayyil  20.4607   45.5779     29.14        13
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_ideal[['City','Country','Lat','Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                          City Country      Lat       Lng  Humidity Hotel Name
# 88                    bazarak      AF  35.3129   69.5152        47
# 91                sao vicente      BR -23.9631  -46.3919        26
# 92            duque de caxias      BR -22.7856  -43.3117        60
# 94                    winslow      US  35.0242 -110.6974        11
# 117  petropavlovsk-kamchatsky      RU  53.0452  158.6483        53
# 120                   pahrump      US  36.2083 -115.9839        11
# 132                siwa oasis      EG  29.2041   25.5195        45
# 135                   the pas      CA  53.8251 -101.2541        49
# 150                      brak      LY  27.5496   14.2714        29
# 157                    ifrane      MA  33.3333   -5.2500        20
# 180               as sulayyil      SA  20.4607   45.5779        13
# 183                     yreka      US  41.7354 -122.6345        28
# 201               grantsville      US  40.5999 -112.4644        19
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 1000  # 1 km
limit = 1
params = {
    'apiKey': geoapify_key,
    'limit': limit
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, 'Lat']
    longitude = hotel_df.loc[index, 'Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params['filter'] = f"circle:{latitude},{longitude},{radius}"
    params['bias'] = f"proximity:{latitude},{longitude}"
    params['categories'] = "accommodation.hotel"
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# bazarak - nearest hotel: No hotel found
# sao vicente - nearest hotel: No hotel found
# duque de caxias - nearest hotel: No hotel found
# winslow - nearest hotel: No hotel found
# petropavlovsk-kamchatsky - nearest hotel: No hotel found
# pahrump - nearest hotel: No hotel found
# siwa oasis - nearest hotel: No hotel found
# the pas - nearest hotel: No hotel found
# brak - nearest hotel: No hotel found
# ifrane - nearest hotel: No hotel found
# as sulayyil - nearest hotel: No hotel found
# yreka - nearest hotel: No hotel found
# grantsville - nearest hotel: No hotel found
# medea - nearest hotel: No hotel found
# lampazos de naranjo - nearest hotel: No hotel found
# at taj - nearest hotel: No hotel found
# yazd - nearest hotel: No hotel found
# tamanrasset - nearest hotel: No hotel found
# bakanas - nearest hotel: No hotel found
# cedar city - nearest hotel: No hotel found
# sale - nearest hotel: No hotel found
# page - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
city_map_hotel = hotel_df.hvplot.points("Lng", "Lat", geo=True, size = "Humidity", 
                                        color = "City", tiles = "OSM", height=400, width=1000,
                                       hover_cols=city_map_hotel["Hotel Name"])

# Display the map
city_map_hotel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 4
#       1 # Configure the map plot
#       2 city_map_hotel = hotel_df.hvplot.points("Lng", "Lat", geo=True, size = "Humidity",
#       3                                         color = "City", tiles = "OSM", height=400, width=1000,
# ----> 4                                        hover_cols=city_map_hotel["Hotel Name"])
#       6 # Display the map
#       7 city_map_hotel
#
# NameError: name 'city_map_hotel' is not defined

# %% [markdown]
# In the above code for Step 4/5, please provide insight into what is being done incorrectly.  I have tried on multiple occasions to retrieve hotel data with no success.  Pointing out my error will be much appreciated.
